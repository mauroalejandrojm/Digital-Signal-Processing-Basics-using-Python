# %% [markdown]
# ### OOP in Python
# ### Using pyQt5 and another Stuff
# ### Created By Mauro Jimenez

# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal as sg

# %% [markdown]
# #### Types of data

# %%
import numpy as np
v = np.array([[1, 2, 3],[2,3,5]])
print(v)
v0 = np.zeros([3,1]) 
print(v0)
v1 = np.ones([1,5])
print(v1)
m = np.matrix('1,2,3 ; 4,5,6')  #Matriz
print(m)
m_T = m.T
print(m_T.shape)
R = np.arange(5)
print(R)
R_1 = np.arange(3,6)
print(R_1)
R_2 = np.arange(0,11,2) # (T_ini, T_fin, Ts)
print(R_2)
R_3 = np.linspace(0,5,10) #(T_ini, T_fin, NúmeroMuestras)
print(R_3)
v_1 = np.array([1,2,3])
v_2 = np.array([2,4,6])
v_mult = v_1*v_2
print(v_mult)
v_dot = np.dot(v_1,v_2.transpose())
print(v_dot)
v_Div = v_1/v_2
print(v_Div)
# Out:
# [[1 2 3]
#  [2 3 5]]
# [[0.]
#  [0.]
#  [0.]]
# [[1. 1. 1. 1. 1.]]
# [[1 2 3]
#  [4 5 6]]
# (3, 2)
# [0 1 2 3 4]
# [3 4 5]
# [ 0  2  4  6  8 10]
# [0.         0.55555556 1.11111111 1.66666667 2.22222222 2.77777778
#  3.33333333 3.88888889 4.44444444 5.        ]
# [ 2  8 18]
# 28
# [0.5 0.5 0.5]

# %% [markdown]
# #### Arithmetic operators

# %%
a = 1
b = 3
c = -5.3
d = a+((b-c)**(b/2))
print(int(d))
# Out:
# 24

# %% [markdown]
# #### Signal Generation

# %%
# Continous Signal
t = np.linspace(0, 1, 500, endpoint=False)
plt.figure()
fig, ax = plt.subplots(figsize=(16,4))
sig = np.sin(2 * np.pi * t)
plt.subplot(1, 2, 1)
plt.plot(t, sig)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('time(s)')
plt.ylabel('voltage(V)')
Fs = 5000
f = 5
sample = 1000
x = np.arange(sample)
y = np.sin(2 * np.pi * f * x / Fs)
plt.subplot(1, 2, 2)
plt.plot(x, y)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('sample(n)')
plt.ylabel('voltage(V)')
plt.show()

# %%
# Discrete Sinusoidal Signal
t = np.linspace(0, 1, 50, endpoint=False)
plt.figure()
fig, ax = plt.subplots(figsize=(16,4))
sig = np.sin(2 * np.pi * t)
plt.subplot(1, 2, 1)
plt.stem(t, sig)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('time(s)')
plt.ylabel('voltage(V)')
Fs = 5000
f = 5
sample = 1000
x = np.arange(sample)
y = np.sin(2 * np.pi * f * x / Fs)
plt.subplot(1, 2, 2)
plt.stem(x, y)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('sample(n)')
plt.ylabel('voltage(V)')
plt.show()

# %%
# Discrete Square Signal
t = np.linspace(0, 1, 50, endpoint=False)
plt.figure()
fig, ax = plt.subplots(figsize=(16,4))
sig = 2*sg.square(2*np.pi*2*t, duty=0.3)
plt.subplot(1, 2, 1)
plt.stem(t, sig)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('time(s)')
plt.ylabel('voltage(V)')
Fs = 1000
f = 5
sample = 1000
x = np.arange(sample)
y = 2*sg.square(2*np.pi*2*x/Fs, duty=0.5)
plt.subplot(1, 2, 2)
plt.stem(x, y)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('sample(n)')
plt.ylabel('voltage(V)')
plt.show()

# %%
# Discrete Triangle Signal
t = np.linspace(0, 1, 50, endpoint=False)
plt.figure()
fig, ax = plt.subplots(figsize=(16,4))
sig = 2*sg.sawtooth(2*np.pi*t, width=0.2)
plt.subplot(1, 2, 1)
plt.stem(t, sig)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('time(s)')
plt.ylabel('voltage(V)')
Fs = 1000
f = 5
sample = 1000
x = np.arange(sample)
y = 2*sg.sawtooth(2*np.pi*x/Fs, width=0.5)
plt.subplot(1, 2, 2)
plt.stem(x, y)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('sample(n)')
plt.ylabel('voltage(V)')
plt.show()

# %%
# Discrete Square Signal
t = np.linspace(0, 1, 50, endpoint=False)
plt.figure()
fig, ax = plt.subplots(figsize=(16,4))
sig = sg.unit_impulse(50, 'mid')
plt.subplot(1, 2, 1)
plt.stem(t, sig)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('time(s)')
plt.ylabel('voltage(V)')
t = np.linspace(0, 1, 50, endpoint=False)
sig = sg.unit_impulse(50, 'mid')
plt.subplot(1, 2, 2)
plt.plot(t, sig)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('time(s)')
plt.ylabel('voltage(V)')
plt.show()

# %%
# Discrete Square Signal
t_ini = -1
t_fin = 1
dt = 0.001
t = np.arange(t_ini,t_fin,dt)
u0 = np.piecewise(t,t>=-0.3,[2,1])
plt.figure()
fig, ax = plt.subplots(figsize=(16,4))
sig = sg.unit_impulse(50, 'mid')
plt.subplot(1, 2, 1)
plt.plot(t, u0)
plt.xlim(-1,3)
plt.ylim(0,2.5)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('t')
plt.ylabel('escalon u(t)')
t = np.linspace(0, 1, 50, endpoint=False)
imp = 0
dt = 0.001
delta = np.piecewise(t,t>=0,[1,0])
delta_dt = np.piecewise(t,t>=imp+dt,[1,0])
unimpulso = delta - delta_dt
plt.subplot(1, 2, 2)
plt.plot(t, unimpulso)
plt.xlim(-1,1)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('time(s)')
plt.ylabel('voltage(V)')
plt.show()

# %%
# Discrete Square Signal
t_ini = -1
t_fin = 1
dt = 0.001
t = np.arange(t_ini,t_fin,dt)
z = np.exp(t)
plt.figure()
fig, ax = plt.subplots(figsize=(16,4))
sig = sg.unit_impulse(50, 'mid')
plt.subplot(1, 2, 1)
plt.plot(t, z)
plt.xlim(-1,3)
plt.ylim(0,2.5)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('t')
plt.ylabel('escalon u(t)')
t1 = np.arange(-10,10,0.01)
w = sg.square(t1)
unimpulso = delta - delta_dt
plt.subplot(1, 2, 2)
plt.plot(t1, w)
plt.xlim(-1,1)
plt.grid(color='#000000', linestyle='-', linewidth=0.5)
plt.xlabel('time(s)')
plt.ylabel('voltage(V)')
plt.show()

# %%
lti = signal.lti([0.5], [1.0, 0.4])
plt.figure()
fig, ax = plt.subplots(figsize=(16,4))
t, y = signal.step(np.array([-3,-2,0,2]))
plt.subplot(1, 2, 1)
plt.plot(t, y)
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.title('Step response for 1. Order Lowpass')
plt.grid()
plt.subplot(1, 2, 2)
plt.stem(t, y)
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.title('Step response for 1. Order Lowpass')
plt.show()

# %% [markdown]
# #### Signal Operations

# %%
#Amplitude scaling

plt.figure()
fig, ax = plt.subplots(figsize=(16,4))
A = 4
t1 = np.arange(-1,1,0.01)
Y = np.sin(2*np.pi*t1)
Y_Amp = A*np.sin(2*np.pi*t1)
plt.subplot(121)
plt.plot(t1,Y)
plt.title('Señal Original')
plt.subplot(122)
plt.plot(t1,Y_Amp)
plt.show()

# %%
#Time scaling

plt.figure()
fig, ax = plt.subplots(figsize=(16,4))
a = 5
Y_Time = np.sin(2*np.pi*a*t)
plt.subplot(121)
plt.plot(t,Y_Time)
plt.title('Señal Original')
plt.subplot(122)
plt.plot(t,Y_Time)
plt.show()

# %%
# Shifting 

plt.figure(figsize=(16,4))
t0 = 2
t = np.arange(-1,1,0.01)
Y = np.sin(2*np.pi*t)
Y_Des = np.sin(2*np.pi*t-t0)
plt.show()
plt.figure()
plt.plot(t,Y,t,Y_Des)
plt.show()

# %% [markdown]
# #### Interactive plots in Jupyter

# %%
# %matplotlib inline
from ipywidgets import interact
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

t_ini = -1
t_fin = 1
dt = 0.001
def f(t0):
    #sns.distplot(np.random.normal(1, t0, 1000))
    t = np.arange(t_ini,t_fin,dt)
    y1 = np.cos(2*np.pi*t*1/2)
    y2 = np.cos(2*np.pi*t*1/2-t0)
    plt.plot(t,y1,t,y2)
    plt.show()
interact(f, t0 = (0,10))
# Out:
# interactive(children=(IntSlider(value=5, description='t0', max=10), Output()), _dom_classes=('widget-interact'…
# <function __main__.f(t0)>
